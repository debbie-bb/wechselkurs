# %%
import urllib.request
import json
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (Python 3.11.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# CSV mit historischen Daten laden
df_hist = pd.read_csv("Users/<Ihr_Username>/london_bikeshare.csv")

# Datumsspalte in Datumsformat umwandeln
df_hist["timestamp"] = pd.to_datetime(df_hist["timestamp"])

df_hist.info()
